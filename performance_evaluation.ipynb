# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

# %% [markdown]
# ## Evaluation

# %%
# Clustering silhouette coefficient and adjusted rand index values

dataset = ['d1','d1','d1','d1',
           'd1','d1','d1','d1',
           'd1','d1','d1','d1',
           'd2','d2','d2','d2',
           'd2','d2','d2','d2',
           'd2','d2','d2','d2',
           'd3','d3','d3','d3',
           'd3','d3','d3','d3',
           'd3','d3','d3','d3']

transformation = ['original', 'original', 'original', 'original',
                  'standardized', 'standardized', 'standardized','standardized',
                  'pca', 'pca', 'pca','pca',
                  'original','original', 'original', 'original', 
                  'standardized', 'standardized', 'standardized', 'standardized',
                  'pca','pca', 'pca', 'pca',
                  'original','original', 'original', 'original', 
                  'standardized','standardized', 'standardized', 'standardized',
                  'pca','pca', 'pca', 'pca']

clustering = ['agglomerative','SC_package', 'SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST']

silhouette = [0.39, -0.23, 0.99, 0.6,
              0.03, 0.04, 0.73, 0.4,
              0.41, 0.3, 0.39, 0.51,
              0.25, -0.14, 0.99, 0.58,
              0.02, 0.02, 0.92, 0.44,
              0.43, 0.45, 0.89, 0.63,
              0.34, -0.44, 0.84, 0.48,
              0.05, 0.06, 0.84, 0.27,
              0.39, 0.24, 0.77, 0.59]

adjusted_rand = [0.16, -0.02, 0.19, 0.16,
                 0.27, 0.24, 0.08, 0.22,
                 0.19, 0.26, 0.02, 0.17,
                 -0.01, 0.02, 0.05, 0.05,
                 0.04, 0.14, 0.02, 0.16,
                 0.14, 0.14, 0.02, 0.05,
                 0.08, -0.01, 0.11, 0.09,
                 0.14, 0.21, 0.01, 0.18,
                 0.17, 0.15, 0.08, 0.14]

df_clustering = pd.DataFrame(
    {'dataset': dataset,
     'transformation': transformation,
     'clustering': clustering,
     'silhouette': silhouette,
     'adjusted_rand': adjusted_rand
    })

df_clustering
# Out:
#    dataset transformation     clustering  silhouette  adjusted_rand
# 0       d1       original  agglomerative        0.39           0.16
# 1       d1       original     SC_package       -0.23          -0.02
# 2       d1       original         SC_NJW        0.99           0.19
# 3       d1       original          SC_ST        0.60           0.16
# 4       d1   standardized  agglomerative        0.03           0.27
# 5       d1   standardized     SC_package        0.04           0.24
# 6       d1   standardized         SC_NJW        0.73           0.08
# 7       d1   standardized          SC_ST        0.40           0.22
# 8       d1            pca  agglomerative        0.41           0.19
# 9       d1            pca     SC_package        0.30           0.26
# 10      d1            pca         SC_NJW        0.39           0.02
# 11      d1            pca          SC_ST        0.51           0.17
# 12      d2       original  agglomerative        0.25          -0.01
# 13      d2       original     SC_package       -0.14           0.02
# 14      d2       original         SC_NJW        0.99           0.05
# 15      d2       original          SC_ST        0.58           0.05
# 16      d2   standardized  agglomerative        0.02           0.04
# 17      d2   standardized     SC_package        0.02           0.14
# 18      d2   standardized         SC_NJW        0.92           0.02
# 19      d2   standardized          SC_ST        0.44           0.16
# 20      d2            pca  agglomerative        0.43           0.14
# 21      d2            pca     SC_package        0.45           0.14
# 22      d2            pca         SC_NJW        0.89           0.02
# 23      d2            pca          SC_ST        0.63           0.05
# 24      d3       original  agglomerative        0.34           0.08
# 25      d3       original     SC_package       -0.44          -0.01
# 26      d3       original         SC_NJW        0.84           0.11
# 27      d3       original          SC_ST        0.48           0.09
# 28      d3   standardized  agglomerative        0.05           0.14
# 29      d3   standardized     SC_package        0.06           0.21
# 30      d3   standardized         SC_NJW        0.84           0.01
# 31      d3   standardized          SC_ST        0.27           0.18
# 32      d3            pca  agglomerative        0.39           0.17
# 33      d3            pca     SC_package        0.24           0.15
# 34      d3            pca         SC_NJW        0.77           0.08
# 35      d3            pca          SC_ST        0.59           0.14

# %%
df_clustering.groupby('dataset').mean()
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_8496\2929525990.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_clustering.groupby('dataset').mean()
#          silhouette  adjusted_rand
# dataset
# d1         0.380000       0.161667
# d2         0.456667       0.068333
# d3         0.369167       0.112500

# %%
df_clustering.groupby('transformation').mean()
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_8496\1147183303.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_clustering.groupby('transformation').mean()
#                 silhouette  adjusted_rand
# transformation
# original          0.387500         0.0725
# pca               0.500000         0.1275
# standardized      0.318333         0.1425

# %%
df_clustering.groupby('clustering').mean()
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_8496\106244717.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_clustering.groupby('clustering').mean()
#                silhouette  adjusted_rand
# clustering
# SC_NJW           0.817778       0.064444
# SC_ST            0.500000       0.135556
# SC_package       0.033333       0.125556
# agglomerative    0.256667       0.131111

# %%
df_clustering_d1 = df_clustering[df_clustering["dataset"] == "d1"]
df_clustering_d2 = df_clustering[df_clustering["dataset"] == "d2"]
df_clustering_d3 = df_clustering[df_clustering["dataset"] == "d3"]

# %%
# Silhouette coefficient and Adjusted rand index 1
fig, axes = plt.subplots(2, 3, figsize=(22, 12), sharey=False)
sns.set(font_scale = 2.2)

box1 = sns.boxplot(ax = axes[0,0], data=df_clustering, x="dataset", y="silhouette", color = "lightgreen", whis = 7)

box2 = sns.boxplot(ax = axes[0,1], data=df_clustering, x="transformation", y="silhouette", color = "skyblue", whis = 7 )

box3 = sns.boxplot(ax = axes[0,2], data=df_clustering, x="clustering", y="silhouette", color = "coral", whis = 7)

box4 = sns.boxplot(ax = axes[1,0], data=df_clustering, x="dataset", y="adjusted_rand", color = "lightgreen")

box5 = sns.boxplot(ax = axes[1,1], data=df_clustering, x="transformation", y="adjusted_rand", color = "skyblue", whis = 3)

box6 = sns.boxplot(ax = axes[1,2], data=df_clustering, x="clustering", y="adjusted_rand", color = "coral", whis = 5)


box3.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])
box6.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])

box1.set(xlabel="A")
box2.set(xlabel="B")
box3.set(xlabel="C")
box4.set(xlabel="D")
box5.set(xlabel="E")
box6.set(xlabel="F")

box1.set_ylabel('Silhouette Coefficient', fontsize = 25)
box2.set(ylabel=None)
box3.set(ylabel=None)
box4.set_ylabel('Adjusted Rand Index', fontsize = 25)
box5.set(ylabel=None)
box6.set(ylabel=None)

box1.set_xticklabels(box1.get_xticklabels(), size = 21)
box2.set_xticklabels(box2.get_xticklabels(), size = 21)
box3.set_xticklabels(box3.get_xticklabels(), size = 21)
box4.set_xticklabels(box4.get_xticklabels(), size = 21)
box5.set_xticklabels(box5.get_xticklabels(), size = 21)
box6.set_xticklabels(box6.get_xticklabels(), size = 21)

fig.subplots_adjust(wspace=0.15, hspace=0.3)
# fig.savefig("exp1_1.pdf", bbox_inches='tight')

# %%
# Silhouette coefficient and Adjusted rand index 2
fig, axes = plt.subplots(2, 2, figsize=(18, 14), sharey=False)

sns.set(font_scale = 1.5)

# box1 = sns.boxplot(ax = axes[0,0], data=df_clustering, x="dataset", y="silhouette", color = "lightgreen", whis = 5)
# box1.axhline(0.17, ls='--', color = 'red', linewidth = 2, label = 'd1')
# box1.axhline(0.02, ls='--', color = 'blue', linewidth = 2, label = 'd2')

box2 = sns.boxplot(ax = axes[0,0], data=df_clustering, x="transformation", y="silhouette", 
                   hue = "dataset", color = "skyblue", whis = 4)
box2.axhline(0.17, ls='--', color = 'red', linewidth = 2, label = 'd1')
box2.axhline(0.02, ls='--', color = 'blue', linewidth = 2, label = 'd2')

box3 = sns.boxplot(ax = axes[0,1], data=df_clustering, x="clustering", y="silhouette", 
                   hue = "transformation", color = "coral", whis = 4)
box3.axhline(0.17, ls='--', color = 'red', linewidth = 2, label = 'd1')
box3.axhline(0.02, ls='--', color = 'blue', linewidth = 2, label = 'd2')
sns.move_legend(box3, "lower right")

# box4 = sns.boxplot(ax = axes[1,0], data=df_clustering, x="dataset", y="adjusted_rand", color = "lightgreen")
# box4.axhline(0.31, ls='--', color = 'red', linewidth = 2, label = 'd1')
# box4.axhline(0.44, ls='--', color = 'blue', linewidth = 2, label = 'd2')

box5 = sns.boxplot(ax = axes[1,0], data=df_clustering, x="transformation", y="adjusted_rand", 
                   hue = "dataset", color = "skyblue", whis = 4)
box5.axhline(0.31, ls='--', color = 'red', linewidth = 2, label = 'd1')
box5.axhline(0.44, ls='--', color = 'blue', linewidth = 2, label = 'd2')

box6 = sns.boxplot(ax = axes[1,1], data=df_clustering, x="clustering", y="adjusted_rand",
                   hue = "transformation", color = "coral", whis = 4)
box6.axhline(0.31, ls='--', color = 'red', linewidth = 2, label = 'd1')
box6.axhline(0.44, ls='--', color = 'blue', linewidth = 2, label = 'd2')

box2.set_xticklabels(['original','standardized','pca'])
box3.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])
box5.set_xticklabels(['original','standardized','pca'])
box6.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])

# box1.set(xlabel="A")
box2.set(xlabel="A")
box3.set(xlabel="B")
# box4.set(xlabel="D")
box5.set(xlabel="C")
box6.set(xlabel="D")

# box1.set_ylabel('silhouette', fontsize = 18)
box2.set_ylabel('Silhouette Coefficient', fontsize = 22)
box3.set(ylabel=None)
# box4.set_ylabel('adjusted_rand', fontsize = 18)
box5.set_ylabel('Adjusted Rand Index', fontsize = 22)
box6.set(ylabel=None)

# box1.set_xticklabels(box1.get_xticklabels(), size = 16)
box2.set_xticklabels(box2.get_xticklabels(), size = 20)
box3.set_xticklabels(box3.get_xticklabels(), size = 20)
# box4.set_xticklabels(box1.get_xticklabels(), size = 16)
box5.set_xticklabels(box2.get_xticklabels(), size = 20)
box6.set_xticklabels(box3.get_xticklabels(), size = 20)

# box1.set(ylim=(61, 93))
# box2.set(ylim=(61, 93))
# box3.set(ylim=(61, 93))

fig.subplots_adjust(wspace=0.15, hspace=0.25)
#fig.savefig("exp1_2.pdf", bbox_inches='tight')

# %%
# Silhouette coefficient and Adjusted rand index 3
fig, axes = plt.subplots(3, 2, figsize=(18, 24), sharey=False)

sns.set(font_scale = 2.1)

box1 = sns.barplot(ax = axes[0,0], data=df_clustering_d1, x="clustering", y="silhouette", 
                   hue = "transformation")
box1.axhline(0.17, ls='--', color = 'red', linewidth = 3, label = 'd1')

box2 = sns.barplot(ax = axes[0,1], data=df_clustering_d1, x="clustering", y="adjusted_rand", 
                   hue = "transformation")
box2.axhline(0.31, ls='--', color = 'red', linewidth = 3, label = 'd1')
box2.get_legend().remove()


box3 = sns.barplot(ax = axes[1,0], data=df_clustering_d2, x="clustering", y="silhouette", 
                   hue = "transformation")
box3.axhline(0.02, ls='--', color = 'red', linewidth = 3, label = 'd2')
box3.get_legend().remove()

box4 = sns.barplot(ax = axes[1,1], data=df_clustering_d2, x="clustering", y="adjusted_rand", 
                   hue = "transformation")
box4.axhline(0.44, ls='--', color = 'red', linewidth = 3, label = 'd2')
box4.get_legend().remove()


box5 = sns.barplot(ax = axes[2,0], data=df_clustering_d3, x="clustering", y="silhouette", 
                   hue = "transformation")
box5.get_legend().remove()

box6 = sns.barplot(ax = axes[2,1], data=df_clustering_d3, x="clustering", y="adjusted_rand", 
                   hue = "transformation")
box6.get_legend().remove()


box1.set(ylim=(-0.20, 1))
box2.set(ylim=(-0.1, 0.5))
box3.set(ylim=(-0.20, 1))
box4.set(ylim=(-0.1, 0.5))
box5.set(ylim=(-0.20, 1))
box6.set(ylim=(-0.1, 0.5))

box1.set(xlabel="A")
box2.set(xlabel="B")
box3.set(xlabel="C")
box4.set(xlabel="D")
box5.set(xlabel="E")
box6.set(xlabel="F")

box1.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])
box2.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])
box3.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])
box4.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])
box5.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])
box6.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])


box1.set_xticklabels(box1.get_xticklabels(), size = 20)
box1.set_yticklabels(box1.get_yticklabels(), size = 20)


fig.subplots_adjust(wspace=0.2, hspace=0.25)
# fig.savefig("exp1_3.pdf", bbox_inches='tight')
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_9504\1231296627.py:59: UserWarning: FixedFormatter should only be used together with FixedLocator
#   box1.set_yticklabels(box1.get_yticklabels(), size = 20)

# %%
# Classification accuracy and mcc values

transformation = ['original', 'standardized', 'eigen (k)', 'eigen (2k)',
                  'original', 'standardized', 'eigen (k)', 'eigen (2k)',
                  'original', 'standardized', 'eigen (k)', 'eigen (2k)',
                  'original', 'standardized', 'eigen (k)', 'eigen (2k)',
                  'original', 'standardized', 'eigen (k)', 'eigen (2k)',
                  'original', 'standardized', 'eigen (k)', 'eigen (2k)',
                  'original', 'standardized', 'eigen (k)', 'eigen (2k)',
                  'original', 'standardized', 'eigen (k)', 'eigen (2k)',
                  'original', 'standardized', 'eigen (k)', 'eigen (2k)']

dataset = ['d1','d1','d1','d1',
           'd2','d2','d2','d2',
           'd3','d3','d3','d3',
           'd1','d1','d1','d1',
           'd2','d2','d2','d2',
           'd3','d3','d3','d3',
           'd1','d1','d1','d1',
           'd2','d2','d2','d2',
           'd3','d3','d3','d3']

classifier = ['nc','nc','nc','nc',
              'nc','nc','nc','nc',
              'nc','nc','nc','nc',
              'knn','knn','knn','knn',
              'knn','knn','knn','knn',
              'knn','knn','knn','knn',
              'dt','dt','dt','dt',
              'dt','dt','dt','dt',
              'dt','dt','dt','dt']

accuracy = [0.32, 0.42, 0.42, 0.52, 
            0.4, 0.6, 0.45, 0.6,
            0.2, 0.46, 0.33, 0.31,
            0.32, 0.47, 0.42, 0.37, 
            0.45, 0.6, 0.45, 0.4, 
            0.31, 0.38, 0.44, 0.51,
            0.44, 0.44, 0.49, 0.39, 
            0.47, 0.52, 0.47, 0.51, 
            0.47, 0.35, 0.36, 0.42]

mcc = [0.2, 0.28, 0.3, 0.44, 
       0.33, 0.53, 0.2, 0.39, 
       0.09, 0.35, 0.23, 0.2,
       0.14, 0.36, 0.3, 0.24, 
       0.29, 0.42, 0.21, 0.08, 
       0.13, 0.26, 0.31, 0.41,
       0.31, 0.33, 0.38, 0.24, 
       0.18, 0.27, 0.2, 0.26, 
       0.36, 0.22, 0.21, 0.3]

accuracy = [float(x) for x in accuracy]
mcc = [float(x) for x in mcc]

df_classification = pd.DataFrame(
    {'dataset': dataset,
     'transformation': transformation,
     'classifier': classifier,
     'accuracy': accuracy,
     'mcc': mcc
    })

df_classification
# Out:
#    dataset transformation classifier  accuracy   mcc
# 0       d1       original         nc      0.32  0.20
# 1       d1   standardized         nc      0.42  0.28
# 2       d1      eigen (k)         nc      0.42  0.30
# 3       d1     eigen (2k)         nc      0.52  0.44
# 4       d2       original         nc      0.40  0.33
# 5       d2   standardized         nc      0.60  0.53
# 6       d2      eigen (k)         nc      0.45  0.20
# 7       d2     eigen (2k)         nc      0.60  0.39
# 8       d3       original         nc      0.20  0.09
# 9       d3   standardized         nc      0.46  0.35
# 10      d3      eigen (k)         nc      0.33  0.23
# 11      d3     eigen (2k)         nc      0.31  0.20
# 12      d1       original        knn      0.32  0.14
# 13      d1   standardized        knn      0.47  0.36
# 14      d1      eigen (k)        knn      0.42  0.30
# 15      d1     eigen (2k)        knn      0.37  0.24
# 16      d2       original        knn      0.45  0.29
# 17      d2   standardized        knn      0.60  0.42
# 18      d2      eigen (k)        knn      0.45  0.21
# 19      d2     eigen (2k)        knn      0.40  0.08
# 20      d3       original        knn      0.31  0.13
# 21      d3   standardized        knn      0.38  0.26
# 22      d3      eigen (k)        knn      0.44  0.31
# 23      d3     eigen (2k)        knn      0.51  0.41
# 24      d1       original         dt      0.44  0.31
# 25      d1   standardized         dt      0.44  0.33
# 26      d1      eigen (k)         dt      0.49  0.38
# 27      d1     eigen (2k)         dt      0.39  0.24
# 28      d2       original         dt      0.47  0.18
# 29      d2   standardized         dt      0.52  0.27
# 30      d2      eigen (k)         dt      0.47  0.20
# 31      d2     eigen (2k)         dt      0.51  0.26
# 32      d3       original         dt      0.47  0.36
# 33      d3   standardized         dt      0.35  0.22
# 34      d3      eigen (k)         dt      0.36  0.21
# 35      d3     eigen (2k)         dt      0.42  0.30

# %%
df_classification_d1 = df_classification[df_classification["dataset"] == "d1"]
df_classification_d2 = df_classification[df_classification["dataset"] == "d2"]
df_classification_d3 = df_classification[df_classification["dataset"] == "d3"]

# %%
df_classification.groupby('dataset').mean()
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_11040\1151824876.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_classification.groupby('dataset').mean()
#          accuracy       mcc
# dataset
# d1       0.418333  0.293333
# d2       0.493333  0.280000
# d3       0.378333  0.255833

# %%
df_classification.groupby('classifier').mean()
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_11040\1419090284.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_classification.groupby('classifier').mean()
#             accuracy       mcc
# classifier
# dt          0.444167  0.271667
# knn         0.426667  0.262500
# nc          0.419167  0.295000

# %%
df_classification.groupby('transformation').mean()
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_11040\152179224.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_classification.groupby('transformation').mean()
#                 accuracy       mcc
# transformation
# eigen (2k)      0.447778  0.284444
# eigen (k)       0.425556  0.260000
# original        0.375556  0.225556
# standardized    0.471111  0.335556

# %%
# Accuracy and Mathews' Correlation Coefficient 1
fig, axes = plt.subplots(2, 3, figsize=(24, 12), sharey=False)
sns.set(font_scale = 2.2)

box1 = sns.boxplot(ax = axes[0,0], data=df_classification, x="dataset", y="accuracy", color = "lightgreen")
# sns.move_legend(box2, "upper left")
box2 = sns.boxplot(ax = axes[0,1], data=df_classification, x="transformation", y="accuracy", color = "skyblue", whis = 7 )
# sns.move_legend(box2, "upper left")
box3 = sns.boxplot(ax = axes[0,2], data=df_classification, x="classifier", y="accuracy", color = "coral", whis = 7)
# sns.move_legend(box2, "upper left")

box4 = sns.boxplot(ax = axes[1,0], data=df_classification, x="dataset", y="mcc", color = "lightgreen")
box5 = sns.boxplot(ax = axes[1,1], data=df_classification, x="transformation", y="mcc", color = "skyblue", whis = 3)
box6 = sns.boxplot(ax = axes[1,2], data=df_classification, x="classifier", y="mcc", color = "coral", whis = 5)


box2.set_xticklabels(['original','standardized','eigen \n (k)','eigen \n (2k)'])
box5.set_xticklabels(['original','standardized','eigen \n (k)','eigen \n (2k)'])

box1.set(xlabel="A")
box2.set(xlabel="B")
box3.set(xlabel="C")
box4.set(xlabel="D")
box5.set(xlabel="E")
box6.set(xlabel="F")

box1.set_ylabel('Accuracy', fontsize = 25)
box2.set(ylabel=None)
box3.set(ylabel=None)
box4.set_ylabel('MCC', fontsize = 25)
box5.set(ylabel=None)
box6.set(ylabel=None)

box1.set_xticklabels(box1.get_xticklabels(), size = 21)
box2.set_xticklabels(box2.get_xticklabels(), size = 21)
box3.set_xticklabels(box3.get_xticklabels(), size = 21)
box4.set_xticklabels(box4.get_xticklabels(), size = 21)
box5.set_xticklabels(box5.get_xticklabels(), size = 21)
box6.set_xticklabels(box6.get_xticklabels(), size = 21)

fig.subplots_adjust(wspace=0.15, hspace=0.3)
# fig.savefig("exp2_1.pdf", bbox_inches='tight')

# %%
# Accuracy and Mathews' Correlation Coefficient 2
fig, axes = plt.subplots(2, 2, figsize=(20, 16), sharey=False)

sns.set(font_scale = 2)

# box1 = sns.boxplot(ax = axes[0,0], data=df_classification, x="dataset", y="accuracy", color = "lightgreen")
# box1.axhline(0.86, ls='--', color = 'blue', linewidth = 2, label = 'd2')

box2 = sns.boxplot(ax = axes[0,0], data=df_classification, x="transformation", y="accuracy", hue = "dataset",
                   color = "skyblue", whis = 7 )
box2.axhline(0.86, ls='--', color = 'blue', linewidth = 2, label = 'd2')
sns.move_legend(box2, "upper left")

box3 = sns.boxplot(ax = axes[0,1], data=df_classification, x="classifier", y="accuracy", hue = "transformation",
                   color = "coral", whis = 7)
box3.axhline(0.86, ls='--', color = 'blue', linewidth = 2, label = 'd2')
sns.move_legend(box3, "upper left", bbox_to_anchor=(1, 1))

# box4 = sns.boxplot(ax = axes[1,0], data=df_classification, x="dataset", y="mcc", color = "lightgreen")
box5 = sns.boxplot(ax = axes[1,0], data=df_classification, x="transformation", y="mcc", 
                   hue = "dataset", color = "skyblue", whis = 3)
box6 = sns.boxplot(ax = axes[1,1], data=df_classification, x="classifier", y="mcc", 
                   hue = "transformation", color = "coral", whis = 5)
sns.move_legend(box6, "upper left", bbox_to_anchor=(1, 1))

box2.set_xticklabels(['original','standardized','eigen(k)','eigen(2k)'])
box5.set_xticklabels(['original','standardized','eigen(k)','eigen(2k)'])

# box1.set(xlabel="A")
box2.set(xlabel="A")
box3.set(xlabel="B")
# box4.set(xlabel="D")
box5.set(xlabel="C")
box6.set(xlabel="D")

box2.set_ylabel('Accuracy', fontsize = 22)
box3.set(ylabel=None)
box5.set_ylabel('MCC', fontsize = 22)
box6.set(ylabel=None)

# box1.set_xticklabels(box1.get_xticklabels(), size = 14)
box2.set_xticklabels(box2.get_xticklabels(), size = 20)
box3.set_xticklabels(box3.get_xticklabels(), size = 20)
# box4.set_xticklabels(box1.get_xticklabels(), size = 14)
box5.set_xticklabels(box5.get_xticklabels(), size = 20)
box6.set_xticklabels(box6.get_xticklabels(), size = 20)

# box1.set(ylim=(61, 93))
# box2.set(ylim=(61, 93))
# box3.set(ylim=(61, 93))

fig.subplots_adjust(wspace=0.15, hspace=0.25)
#fig.savefig("exp2_2.pdf", bbox_inches='tight')

# %%
# Accuracy and Mathews' Correlation Coefficient 3

fig, axes = plt.subplots(3, 2, figsize=(18, 24), sharey=False)

sns.set(font_scale = 2.1)

box1 = sns.barplot(ax = axes[0,0], data=df_classification_d1, x="classifier", y="accuracy", 
                   hue = "transformation")

box2 = sns.barplot(ax = axes[0,1], data=df_classification_d1, x="classifier", y="mcc", 
                   hue = "transformation")
box2.get_legend().remove()


box3 = sns.barplot(ax = axes[1,0], data=df_classification_d2, x="classifier", y="accuracy", 
                   hue = "transformation")
box3.axhline(0.86, ls='--', color = 'red', linewidth = 3, label = 'd2')
box3.get_legend().remove()

box4 = sns.barplot(ax = axes[1,1], data=df_classification_d2, x="classifier", y="mcc", 
                   hue = "transformation")
box4.get_legend().remove()


box5 = sns.barplot(ax = axes[2,0], data=df_classification_d3, x="classifier", y="accuracy", 
                   hue = "transformation")
box5.get_legend().remove()

box6 = sns.barplot(ax = axes[2,1], data=df_classification_d3, x="classifier", y="mcc", 
                   hue = "transformation")
box6.get_legend().remove()


box1.set(ylim=(0, 1))
box2.set(ylim=(0, 1))
box3.set(ylim=(0, 1))
box4.set(ylim=(0, 1))
box5.set(ylim=(0, 1))
box6.set(ylim=(0, 1))

box1.set(xlabel="A")
box2.set(xlabel="B")
box3.set(xlabel="C")
box4.set(xlabel="D")
box5.set(xlabel="E")
box6.set(xlabel="F")

box1.set_xticklabels(box1.get_xticklabels(), size = 20)
box1.set_yticklabels(box1.get_yticklabels(), size = 20)


fig.subplots_adjust(wspace=0.2, hspace=0.25)
# fig.savefig("exp2_3.pdf", bbox_inches='tight')
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_9504\2148659354.py:49: UserWarning: FixedFormatter should only be used together with FixedLocator
#   box1.set_yticklabels(box1.get_yticklabels(), size = 20)
