# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Experiment 1 and 2

# %%
# Clustering silhouette coefficient and adjusted rand index values

dataset = ['d1','d1','d1','d1',
           'd1','d1','d1','d1',
           'd1','d1','d1','d1',
           'd2','d2','d2','d2',
           'd2','d2','d2','d2',
           'd2','d2','d2','d2',
           'd3','d3','d3','d3',
           'd3','d3','d3','d3',
           'd3','d3','d3','d3']

transformation = ['original', 'original', 'original', 'original',
                  'normalized', 'normalized', 'normalized','normalized',
                  'pca', 'pca', 'pca','pca',
                  'original','original', 'original', 'original', 
                  'normalized', 'normalized', 'normalized', 'normalized',
                  'pca','pca', 'pca', 'pca',
                  'original','original', 'original', 'original', 
                  'normalized','normalized', 'normalized', 'normalized',
                  'pca','pca', 'pca', 'pca']

clustering = ['agglomerative','SC_package', 'SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST',
              'agglomerative','SC_package','SC_NJW', 'SC_ST']

silhouette =  [0.39, -0.23, 0.99, 0.6,
               0.04, 0.04, 0.78, 0.36,
               0.47, 0.38, 0.72, 0.54,
               0.54, -0.26, 0.99, 0.76,
               0.21, 0.19, 0.92, 0.59,
               0.41, 0.38, 0.94, 0.67,
               0.34, -0.44, 0.8, 0.48,
               0.07, 0.07, 0.81, 0.29,
               0.4, 0.25, 0.73, 0.55]

adjusted_rand = [0.16, -0.02, 0.19, 0.16,
                 0.18, 0.12, 0.04, 0.16,
                 0.33, 0.35, 0.05, 0.18,
                 0.01, -0.01, 0.16, 0.01,
                 0.14, 0.06, 0.01, 0.08,
                 0.08, 0.04, 0.01, 0.09,
                 0.08, -0.01, 0.11, 0.09,
                 0.19, 0.23, 0.05, 0.17,
                 0.21, 0.24, 0.3, 0.18]

df_clustering = pd.DataFrame(
    {'dataset': dataset,
     'transformation': transformation,
     'clustering': clustering,
     'silhouette': silhouette,
     'adjusted_rand': adjusted_rand
    })

df_clustering
# Out:
#    dataset transformation     clustering  silhouette  adjusted_rand
# 0       d1       original  agglomerative        0.39           0.16
# 1       d1       original     SC_package       -0.23          -0.02
# 2       d1       original         SC_NJW        0.99           0.19
# 3       d1       original          SC_ST        0.60           0.16
# 4       d1     normalized  agglomerative        0.04           0.18
# 5       d1     normalized     SC_package        0.04           0.12
# 6       d1     normalized         SC_NJW        0.78           0.04
# 7       d1     normalized          SC_ST        0.36           0.16
# 8       d1            pca  agglomerative        0.47           0.33
# 9       d1            pca     SC_package        0.38           0.35
# 10      d1            pca         SC_NJW        0.72           0.05
# 11      d1            pca          SC_ST        0.54           0.18
# 12      d2       original  agglomerative        0.54           0.01
# ...

# %%
df_clustering.groupby('dataset').mean()
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_2432\2929525990.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_clustering.groupby('dataset').mean()
#          silhouette  adjusted_rand
# dataset
# d1         0.423333       0.158333
# d2         0.528333       0.056667
# d3         0.362500       0.153333

# %%
df_clustering.groupby('transformation').mean()
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_2432\1147183303.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_clustering.groupby('transformation').mean()
#                 silhouette  adjusted_rand
# transformation
# original          0.413333       0.077500
# pca               0.536667       0.171667
# standardized      0.364167       0.119167

# %%
df_clustering.groupby('clustering').mean()
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_2432\106244717.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_clustering.groupby('clustering').mean()
#                silhouette  adjusted_rand
# clustering
# SC_NJW           0.853333       0.102222
# SC_ST            0.537778       0.124444
# SC_package       0.042222       0.111111
# agglomerative    0.318889       0.153333

# %%
df_clustering_d1 = df_clustering[df_clustering["dataset"] == "d1"]
df_clustering_d2 = df_clustering[df_clustering["dataset"] == "d2"]
df_clustering_d3 = df_clustering[df_clustering["dataset"] == "d3"]

# %%
# Silhouette coefficient and Adjusted rand index 1
fig, axes = plt.subplots(2, 3, figsize=(22, 12), sharey=False)
sns.set(font_scale = 2.2)

box1 = sns.boxplot(ax = axes[0,0], data=df_clustering, x="dataset", y="silhouette", color = "lightgreen", whis = 7)

box2 = sns.boxplot(ax = axes[0,1], data=df_clustering, x="transformation", y="silhouette", color = "skyblue", whis = 7 )

box3 = sns.boxplot(ax = axes[0,2], data=df_clustering, x="clustering", y="silhouette", color = "coral", whis = 7)

box4 = sns.boxplot(ax = axes[1,0], data=df_clustering, x="dataset", y="adjusted_rand", color = "lightgreen", whis = 7)

box5 = sns.boxplot(ax = axes[1,1], data=df_clustering, x="transformation", y="adjusted_rand", color = "skyblue", whis = 3)

box6 = sns.boxplot(ax = axes[1,2], data=df_clustering, x="clustering", y="adjusted_rand", color = "coral", whis = 5)


box3.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])
box6.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])

box1.set(xlabel="A")
box2.set(xlabel="B")
box3.set(xlabel="C")
box4.set(xlabel="D")
box5.set(xlabel="E")
box6.set(xlabel="F")

box1.set_ylabel('Silhouette Coefficient', fontsize = 25)
box2.set(ylabel=None)
box3.set(ylabel=None)
box4.set_ylabel('Adjusted Rand Index', fontsize = 25)
box5.set(ylabel=None)
box6.set(ylabel=None)

box1.set_xticklabels(box1.get_xticklabels(), size = 21)
box2.set_xticklabels(box2.get_xticklabels(), size = 21)
box3.set_xticklabels(box3.get_xticklabels(), size = 21)
box4.set_xticklabels(box4.get_xticklabels(), size = 21)
box5.set_xticklabels(box5.get_xticklabels(), size = 21)
box6.set_xticklabels(box6.get_xticklabels(), size = 21)

fig.subplots_adjust(wspace=0.15, hspace=0.3)
fig.savefig("exp1_1.pdf", bbox_inches='tight')

# %%
# Silhouette coefficient and Adjusted rand index 2
fig, axes = plt.subplots(2, 2, figsize=(18, 14), sharey=False)

sns.set(font_scale = 1.5)

# box1 = sns.boxplot(ax = axes[0,0], data=df_clustering, x="dataset", y="silhouette", color = "lightgreen", whis = 5)
# box1.axhline(0.17, ls='--', color = 'red', linewidth = 2, label = 'd1')
# box1.axhline(0.02, ls='--', color = 'blue', linewidth = 2, label = 'd2')

box2 = sns.boxplot(ax = axes[0,0], data=df_clustering, x="transformation", y="silhouette", 
                   hue = "dataset", color = "skyblue", whis = 4)
box2.axhline(0.17, ls='--', color = 'red', linewidth = 2, label = 'd1')
box2.axhline(0.02, ls='--', color = 'blue', linewidth = 2, label = 'd2')

box3 = sns.boxplot(ax = axes[0,1], data=df_clustering, x="clustering", y="silhouette", 
                   hue = "transformation", color = "coral", whis = 4)
box3.axhline(0.17, ls='--', color = 'red', linewidth = 2, label = 'd1')
box3.axhline(0.02, ls='--', color = 'blue', linewidth = 2, label = 'd2')
sns.move_legend(box3, "lower right")

# box4 = sns.boxplot(ax = axes[1,0], data=df_clustering, x="dataset", y="adjusted_rand", color = "lightgreen")
# box4.axhline(0.31, ls='--', color = 'red', linewidth = 2, label = 'd1')
# box4.axhline(0.44, ls='--', color = 'blue', linewidth = 2, label = 'd2')

box5 = sns.boxplot(ax = axes[1,0], data=df_clustering, x="transformation", y="adjusted_rand", 
                   hue = "dataset", color = "skyblue", whis = 4)
box5.axhline(0.31, ls='--', color = 'red', linewidth = 2, label = 'd1')
box5.axhline(0.44, ls='--', color = 'blue', linewidth = 2, label = 'd2')

box6 = sns.boxplot(ax = axes[1,1], data=df_clustering, x="clustering", y="adjusted_rand",
                   hue = "transformation", color = "coral", whis = 4)
box6.axhline(0.31, ls='--', color = 'red', linewidth = 2, label = 'd1')
box6.axhline(0.44, ls='--', color = 'blue', linewidth = 2, label = 'd2')

box2.set_xticklabels(['original','standardized','pca'])
box3.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])
box5.set_xticklabels(['original','standardized','pca'])
box6.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])

# box1.set(xlabel="A")
box2.set(xlabel="A")
box3.set(xlabel="B")
# box4.set(xlabel="D")
box5.set(xlabel="C")
box6.set(xlabel="D")

# box1.set_ylabel('silhouette', fontsize = 18)
box2.set_ylabel('Silhouette Coefficient', fontsize = 22)
box3.set(ylabel=None)
# box4.set_ylabel('adjusted_rand', fontsize = 18)
box5.set_ylabel('Adjusted Rand Index', fontsize = 22)
box6.set(ylabel=None)

# box1.set_xticklabels(box1.get_xticklabels(), size = 16)
box2.set_xticklabels(box2.get_xticklabels(), size = 20)
box3.set_xticklabels(box3.get_xticklabels(), size = 20)
# box4.set_xticklabels(box1.get_xticklabels(), size = 16)
box5.set_xticklabels(box2.get_xticklabels(), size = 20)
box6.set_xticklabels(box3.get_xticklabels(), size = 20)

# box1.set(ylim=(61, 93))
# box2.set(ylim=(61, 93))
# box3.set(ylim=(61, 93))

fig.subplots_adjust(wspace=0.15, hspace=0.25)
#fig.savefig("exp1_2.pdf", bbox_inches='tight')

# %%
# Silhouette coefficient and Adjusted rand index 3
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=False)
sns.set(font_scale = 2.1)

box1 = sns.barplot(ax = axes[0], data=df_clustering_d1, x="clustering", y="silhouette", 
                   hue = "transformation")
box1.axhline(0.17, ls='--', color = 'red', linewidth = 3, label = 'd1')
sns.move_legend(box1, "lower center", bbox_to_anchor=(1.1, 1), ncol=3, title=None, frameon=False)

box2 = sns.barplot(ax = axes[1], data=df_clustering_d1, x="clustering", y="adjusted_rand", 
                   hue = "transformation")
box2.axhline(0.31, ls='--', color = 'red', linewidth = 3, label = 'd1')
box2.get_legend().remove()


box1.set(ylim=(-0.20, 1))
box2.set(ylim=(-0.1, 0.5))


box1.set(xlabel="A")
box2.set(xlabel="B")
box1.set(ylabel="silhouette coefficient")
box2.set(ylabel="adjusted rand index")


box1.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])
box2.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])

box1.set_xticklabels(box1.get_xticklabels(), size = 22)
box2.set_yticklabels(box2.get_yticklabels(), size = 22)


fig.subplots_adjust(wspace=0.2, hspace=0.25)
fig.savefig("exp1_2_1.pdf", bbox_inches='tight')
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_2432\2629358809.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   box2.set_yticklabels(box2.get_yticklabels(), size = 22)

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=False)
sns.set(font_scale = 2.1)

box3 = sns.barplot(ax = axes[0], data=df_clustering_d2, x="clustering", y="silhouette", 
                   hue = "transformation")
box3.axhline(0.02, ls='--', color = 'red', linewidth = 3, label = 'd2')
sns.move_legend(box3, "lower center", bbox_to_anchor=(1.1, 1), ncol=3, title=None, frameon=False)

box4 = sns.barplot(ax = axes[1], data=df_clustering_d2, x="clustering", y="adjusted_rand", 
                   hue = "transformation")
box4.axhline(0.44, ls='--', color = 'red', linewidth = 3, label = 'd2')
box4.get_legend().remove()

box3.set(ylim=(-0.20, 1))
box4.set(ylim=(-0.1, 0.5))

box3.set(xlabel="A")
box4.set(xlabel="B")
box3.set(ylabel="silhouette coefficient")
box4.set(ylabel="adjusted rand index")

box3.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])
box4.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])

fig.subplots_adjust(wspace=0.2, hspace=0.25)
fig.savefig("exp1_2_2.pdf", bbox_inches='tight')

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=False)
sns.set(font_scale = 2.1)

box5 = sns.barplot(ax = axes[0], data=df_clustering_d3, x="clustering", y="silhouette", 
                   hue = "transformation")
sns.move_legend(box5, "lower center", bbox_to_anchor=(1.1, 1), ncol=3, title=None, frameon=False)

box6 = sns.barplot(ax = axes[1], data=df_clustering_d3, x="clustering", y="adjusted_rand", 
                   hue = "transformation")
box6.get_legend().remove()

box5.set(ylim=(-0.20, 1))
box6.set(ylim=(-0.1, 0.5))

box5.set(xlabel="A")
box6.set(xlabel="B")
box5.set(ylabel="silhouette coefficient")
box6.set(ylabel="adjusted rand index")

box5.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])
box6.set_xticklabels(['agglomerative','SC\n(package)','SC\n(NJW)', 'SC\n(ST)'])

fig.subplots_adjust(wspace=0.2, hspace=0.25)
fig.savefig("exp1_2_3.pdf", bbox_inches='tight')

# %% [markdown]
# ### Experiment 2 and 3

# %%
# Classification accuracy and mcc values

transformation = ['original', 'normalized', 'eigen (k)', 'eigen (2k)',
                  'original', 'normalized', 'eigen (k)', 'eigen (2k)',
                  'original', 'normalized', 'eigen (k)', 'eigen (2k)',
                  'original', 'normalized', 'eigen (k)', 'eigen (2k)',
                  'original', 'normalized', 'eigen (k)', 'eigen (2k)',
                  'original', 'normalized', 'eigen (k)', 'eigen (2k)',
                  'original', 'normalized', 'eigen (k)', 'eigen (2k)',
                  'original', 'normalized', 'eigen (k)', 'eigen (2k)',
                  'original', 'normalized', 'eigen (k)', 'eigen (2k)',
                  'original', 'normalized', 'eigen (k)', 'eigen (2k)',
                  'original', 'normalized', 'eigen (k)', 'eigen (2k)',
                  'original', 'normalized', 'eigen (k)', 'eigen (2k)']

dataset = ['d1','d1','d1','d1',
           'd2','d2','d2','d2',
           "d2_benchmark", "d2_benchmark", "d2_benchmark", "d2_benchmark",
           'd3','d3','d3','d3',
           'd1','d1','d1','d1',
           'd2','d2','d2','d2',
           "d2_benchmark", "d2_benchmark", "d2_benchmark", "d2_benchmark",
           'd3','d3','d3','d3',
           'd1','d1','d1','d1',
           'd2','d2','d2','d2',
           "d2_benchmark", "d2_benchmark", "d2_benchmark", "d2_benchmark",
           'd3','d3','d3','d3']

classifier = ['nc','nc','nc','nc',
              'nc','nc','nc','nc',
              'nc','nc','nc','nc',
              'nc','nc','nc','nc',
              'knn','knn','knn','knn',
              'knn','knn','knn','knn',
              'knn','knn','knn','knn',
              'knn','knn','knn','knn',
              'dt','dt','dt','dt',
              'dt','dt','dt','dt',
              'dt','dt','dt','dt',
              'dt','dt','dt','dt']

accuracy = [0.42, 0.37, 0.47, 0.42,
            0.5, 0.45, 0.45, 0.55,
            0.49, 0.54, 0.45, 0.56,
            0.21, 0.44, 0.33, 0.33,
            0.47, 0.47, 0.42, 0.37,
            0.4, 0.4, 0.5, 0.45,
            0.46, 0.63, 0.54, 0.64,
            0.31, 0.38, 0.36, 0.41,
            0.47, 0.42, 0.47, 0.42,
            0.55, 0.35, 0.6, 0.5,
            0.46, 0.63, 0.54, 0.64,
            0.49, 0.38, 0.38, 0.44]

mcc = [0.29, 0.21, 0.37, 0.33,
        0.43, 0.27, 0.27, 0.36,
        0.31, 0.34, 0.2, 0.36,
        0.09, 0.32, 0.22, 0.23,
        0.36, 0.36, 0.3, 0.24,
        0.21, 0.2, 0.28, 0.23,
        0.25, 0.47, 0.33, 0.47,
        0.13, 0.24, 0.23, 0.28,
        0.36, 0.29, 0.38, 0.3,
        0.37, 0.03, 0.42, 0.28,
        0.25, 0.47, 0.2, 0.47,
        0.38, 0.27, 0.27, 0.32]

accuracy = [float(x) for x in accuracy]
mcc = [float(x) for x in mcc]

df_classification = pd.DataFrame(
    {'dataset': dataset,
     'transformation': transformation,
     'classifier': classifier,
     'accuracy': accuracy,
     'mcc': mcc
    })

df_classification
# Out:
#          dataset transformation classifier  accuracy   mcc
# 0             d1       original         nc      0.42  0.29
# 1             d1     normalized         nc      0.37  0.21
# 2             d1      eigen (k)         nc      0.47  0.37
# 3             d1     eigen (2k)         nc      0.42  0.33
# 4             d2       original         nc      0.50  0.43
# 5             d2     normalized         nc      0.45  0.27
# 6             d2      eigen (k)         nc      0.45  0.27
# 7             d2     eigen (2k)         nc      0.55  0.36
# 8   d2_benchmark       original         nc      0.49  0.31
# 9   d2_benchmark     normalized         nc      0.54  0.34
# 10  d2_benchmark      eigen (k)         nc      0.45  0.20
# 11  d2_benchmark     eigen (2k)         nc      0.56  0.36
# 12            d3       original         nc      0.21  0.09
# 13            d3     normalized         nc      0.44  0.32
# 14            d3      eigen (k)         nc      0.33  0.22
# ...

# %%
df_classification.groupby('dataset').mean()
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_2432\1151824876.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_classification.groupby('dataset').mean()
#               accuracy       mcc
# dataset
# d1            0.432500  0.315833
# d2            0.475000  0.279167
# d2_benchmark  0.548333  0.343333
# d3            0.371667  0.248333

# %%
df_classification.groupby('classifier').mean()
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_2432\1419090284.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_classification.groupby('classifier').mean()
#             accuracy      mcc
# classifier
# dt          0.483750  0.31625
# knn         0.450625  0.28625
# nc          0.436250  0.28750

# %%
df_classification.groupby('transformation').mean()
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_2432\152179224.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_classification.groupby('transformation').mean()
#                 accuracy       mcc
# transformation
# eigen (2k)      0.477500  0.322500
# eigen (k)       0.459167  0.289167
# original        0.435833  0.285833
# standardized    0.455000  0.289167

# %%
df_classification_sub = df_classification[df_classification["dataset"] != "d2_benchmark"]

# %%
# Accuracy and Mathews' Correlation Coefficient 1
fig, axes = plt.subplots(2, 3, figsize=(24, 12), sharey=False)
sns.set(font_scale = 2.2)

box1 = sns.boxplot(ax = axes[0,0], data=df_classification_sub, x="dataset", y="accuracy", color = "lightgreen")
# sns.move_legend(box2, "upper left")
box2 = sns.boxplot(ax = axes[0,1], data=df_classification_sub, x="transformation", y="accuracy", color = "skyblue", whis = 7 )
# sns.move_legend(box2, "upper left")
box3 = sns.boxplot(ax = axes[0,2], data=df_classification_sub, x="classifier", y="accuracy", color = "coral", whis = 7)
# sns.move_legend(box2, "upper left")

box4 = sns.boxplot(ax = axes[1,0], data=df_classification_sub, x="dataset", y="mcc", color = "lightgreen", whis = 7)
box5 = sns.boxplot(ax = axes[1,1], data=df_classification_sub, x="transformation", y="mcc", color = "skyblue", whis = 3)
box6 = sns.boxplot(ax = axes[1,2], data=df_classification_sub, x="classifier", y="mcc", color = "coral", whis = 5)


box2.set_xticklabels(['original','normalized','eigen \n (k)','eigen \n (2k)'])
box5.set_xticklabels(['original','normalized','eigen \n (k)','eigen \n (2k)'])

box1.set(xlabel="A")
box2.set(xlabel="B")
box3.set(xlabel="C")
box4.set(xlabel="D")
box5.set(xlabel="E")
box6.set(xlabel="F")

box1.set_ylabel('accuracy', fontsize = 25)
box2.set(ylabel=None)
box3.set(ylabel=None)
box4.set_ylabel('mcc', fontsize = 25)
box5.set(ylabel=None)
box6.set(ylabel=None)

box1.set_xticklabels(box1.get_xticklabels(), size = 21)
box2.set_xticklabels(box2.get_xticklabels(), size = 21)
box3.set_xticklabels(box3.get_xticklabels(), size = 21)
box4.set_xticklabels(box4.get_xticklabels(), size = 21)
box5.set_xticklabels(box5.get_xticklabels(), size = 21)
box6.set_xticklabels(box6.get_xticklabels(), size = 21)

fig.subplots_adjust(wspace=0.15, hspace=0.3)
fig.savefig("exp2_1.pdf", bbox_inches='tight')

# %%
# Accuracy and Mathews' Correlation Coefficient 2
fig, axes = plt.subplots(2, 2, figsize=(20, 16), sharey=False)

sns.set(font_scale = 2)

# box1 = sns.boxplot(ax = axes[0,0], data=df_classification, x="dataset", y="accuracy", color = "lightgreen")
# box1.axhline(0.86, ls='--', color = 'blue', linewidth = 2, label = 'd2')

box2 = sns.boxplot(ax = axes[0,0], data=df_classification, x="transformation", y="accuracy", hue = "dataset",
                   color = "skyblue", whis = 7 )
box2.axhline(0.86, ls='--', color = 'blue', linewidth = 2, label = 'd2')
sns.move_legend(box2, "upper left")

box3 = sns.boxplot(ax = axes[0,1], data=df_classification, x="classifier", y="accuracy", hue = "transformation",
                   color = "coral", whis = 7)
box3.axhline(0.86, ls='--', color = 'blue', linewidth = 2, label = 'd2')
sns.move_legend(box3, "upper left", bbox_to_anchor=(1, 1))

# box4 = sns.boxplot(ax = axes[1,0], data=df_classification, x="dataset", y="mcc", color = "lightgreen")
box5 = sns.boxplot(ax = axes[1,0], data=df_classification, x="transformation", y="mcc", 
                   hue = "dataset", color = "skyblue", whis = 3)
box6 = sns.boxplot(ax = axes[1,1], data=df_classification, x="classifier", y="mcc", 
                   hue = "transformation", color = "coral", whis = 5)
sns.move_legend(box6, "upper left", bbox_to_anchor=(1, 1))

box2.set_xticklabels(['original','standardized','eigen(k)','eigen(2k)'])
box5.set_xticklabels(['original','standardized','eigen(k)','eigen(2k)'])

# box1.set(xlabel="A")
box2.set(xlabel="A")
box3.set(xlabel="B")
# box4.set(xlabel="D")
box5.set(xlabel="C")
box6.set(xlabel="D")

box2.set_ylabel('Accuracy', fontsize = 22)
box3.set(ylabel=None)
box5.set_ylabel('MCC', fontsize = 22)
box6.set(ylabel=None)

# box1.set_xticklabels(box1.get_xticklabels(), size = 14)
box2.set_xticklabels(box2.get_xticklabels(), size = 20)
box3.set_xticklabels(box3.get_xticklabels(), size = 20)
# box4.set_xticklabels(box1.get_xticklabels(), size = 14)
box5.set_xticklabels(box5.get_xticklabels(), size = 20)
box6.set_xticklabels(box6.get_xticklabels(), size = 20)

# box1.set(ylim=(61, 93))
# box2.set(ylim=(61, 93))
# box3.set(ylim=(61, 93))

fig.subplots_adjust(wspace=0.15, hspace=0.25)
#fig.savefig("exp2_2.pdf", bbox_inches='tight')

# %%
df_classification_d1 = df_classification[df_classification["dataset"] == "d1"]
df_classification_d2 = df_classification[df_classification["dataset"] == "d2"]
df_classification_d2_benchmark = df_classification[df_classification["dataset"] == "d2_benchmark"]
df_classification_d3 = df_classification[df_classification["dataset"] == "d3"]

# %%
# Accuracy and Mathews' Correlation Coefficient 3

fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=False)
sns.set(font_scale = 2.2)

box1 = sns.barplot(ax = axes[0], data=df_classification_d1, x="classifier", y="accuracy", 
                   hue = "transformation")
sns.move_legend(box1, "lower center", bbox_to_anchor=(1.1, 1), ncol=4, title=None, frameon=False)


box2 = sns.barplot(ax = axes[1], data=df_classification_d1, x="classifier", y="mcc", 
                   hue = "transformation")
box2.get_legend().remove()


box1.set(ylim=(0, 1))
box2.set(ylim=(0, 1))


box1.set(xlabel="A")
box2.set(xlabel="B")


box1.set_xticklabels(box1.get_xticklabels(), size = 20)
box1.set_yticklabels(box1.get_yticklabels(), size = 20)


fig.subplots_adjust(wspace=0.2, hspace=0.25)
fig.savefig("exp2_2_1.pdf", bbox_inches='tight')
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_2432\750783640.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   box1.set_yticklabels(box1.get_yticklabels(), size = 20)

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=False)
sns.set(font_scale = 2.2)

box3 = sns.barplot(ax = axes[0], data=df_classification_d2, x="classifier", y="accuracy", 
                   hue = "transformation")
sns.move_legend(box3, "lower center", bbox_to_anchor=(1.1, 1), ncol=4, title=None, frameon=False)

box4 = sns.barplot(ax = axes[1], data=df_classification_d2, x="classifier", y="mcc", 
                   hue = "transformation")
box4.get_legend().remove()

box3.set(ylim=(0, 1))
box4.set(ylim=(0, 1))

box3.set(xlabel="A")
box4.set(xlabel="B")

box3.set_xticklabels(box1.get_xticklabels(), size = 20)
box4.set_yticklabels(box1.get_yticklabels(), size = 20)

fig.subplots_adjust(wspace=0.2, hspace=0.25)
fig.savefig("exp2_2_2a.pdf", bbox_inches='tight')
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_2432\1571615064.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   box4.set_yticklabels(box1.get_yticklabels(), size = 20)

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=False)
sns.set(font_scale = 2.2)

box3 = sns.barplot(ax = axes[0], data=df_classification_d2_benchmark, x="classifier", y="accuracy", 
                   hue = "transformation")
box3.axhline(0.86, ls='--', color = 'red', linewidth = 3, label = 'd2')
sns.move_legend(box3, "lower center", bbox_to_anchor=(1.1, 1), ncol=4, title=None, frameon=False)

box4 = sns.barplot(ax = axes[1], data=df_classification_d2_benchmark, x="classifier", y="mcc", 
                   hue = "transformation")
box4.get_legend().remove()

box3.set(ylim=(0, 1))
box4.set(ylim=(0, 1))

box3.set(xlabel="A")
box4.set(xlabel="B")

box3.set_xticklabels(box1.get_xticklabels(), size = 20)
box4.set_yticklabels(box1.get_yticklabels(), size = 20)

fig.subplots_adjust(wspace=0.2, hspace=0.25)
fig.savefig("exp2_2_2b.pdf", bbox_inches='tight')
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_2432\3301498509.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   box4.set_yticklabels(box1.get_yticklabels(), size = 20)

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=False)
sns.set(font_scale = 2.2)

box5 = sns.barplot(ax = axes[0], data=df_classification_d3, x="classifier", y="accuracy", 
                   hue = "transformation")
sns.move_legend(box5, "lower center", bbox_to_anchor=(1.1, 1), ncol=4, title=None, frameon=False)

box6 = sns.barplot(ax = axes[1], data=df_classification_d3, x="classifier", y="mcc", 
                   hue = "transformation")
box6.get_legend().remove()

box5.set(ylim=(0, 1))
box6.set(ylim=(0, 1))

box5.set(xlabel="A")
box6.set(xlabel="B")

box5.set_xticklabels(box1.get_xticklabels(), size = 20)
box6.set_yticklabels(box1.get_yticklabels(), size = 20)

fig.subplots_adjust(wspace=0.2, hspace=0.25)
fig.savefig("exp2_2_3.pdf", bbox_inches='tight')
# Out:
# C:\Users\49171\AppData\Local\Temp\ipykernel_2432\582556753.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   box6.set_yticklabels(box1.get_yticklabels(), size = 20)

# %%
# Precision and recall for control groups

dataset = ['d1','d1','d1','d1',
           'd1','d1','d1','d1',
           'd1','d1','d1','d1',
           'd2','d2','d2','d2',
           'd2','d2','d2','d2',
           'd2','d2','d2','d2',
           'd3','d3','d3','d3',
           'd3','d3','d3','d3',
           'd3','d3','d3','d3']

transformation = ['original', 'original', 'original',
                  'normalized', 'normalized', 'normalized',
                  'eigen (k)', 'eigen (k)', 'eigen (k)',
                  'eigen (2k)', 'eigen (2k)', 'eigen (2k)',
                  'original', 'original', 'original',
                  'normalized', 'normalized', 'normalized',
                  'eigen (k)', 'eigen (k)', 'eigen (k)',
                  'eigen (2k)', 'eigen (2k)', 'eigen (2k)',
                 'original', 'original', 'original',
                  'normalized', 'normalized', 'normalized',
                  'eigen (k)', 'eigen (k)', 'eigen (k)',
                  'eigen (2k)', 'eigen (2k)', 'eigen (2k)']

classifier = ['nc','knn', 'dt',
              'nc','knn', 'dt',
             'nc','knn', 'dt',
             'nc','knn', 'dt',
             'nc','knn', 'dt',
             'nc','knn', 'dt',
             'nc','knn', 'dt',
             'nc','knn', 'dt',
             'nc','knn', 'dt',
             'nc','knn', 'dt',
             'nc','knn', 'dt',
             'nc','knn', 'dt',]

precision = [0.5, 0.45, 0.57,
            0.36, 0.45, 0.57,
            0.57, 0.56, 0.42,
            0.6, 0.44, 0.62,
            0.33, 0.36, 0.5,
            0.38, 0.36, 0.57,
            0.42, 0.56, 0.57,
            0.44, 0.45, 0.56,
            0.42, 0.33, 0.53,
            0.44, 0.4, 0.55,
            0.6, 0.5, 0.57,
            0.67, 0.5, 0.62]

recall =   [0.8, 1, 0.8,
            0.8, 1, 0.8,
            0.8, 1, 1,
            0.6, 0.8, 1,
            1, 1, 1,
            1, 1, 0.8,
            1, 1, 0.8,
            0, 0.2, 0,
            0.5, 0.9, 0.9,
            0.8, 0.7, 0.7,
            0.3, 0.7, 0.7,
            0.3, 0.8, 0.8]

df_control_pr = pd.DataFrame(
    {'dataset': dataset,
     'transformation': transformation,
     'classifier': classifier,
     'precision': precision,
     'recall': recall
    })

df_control_pr
# Out:
#    dataset transformation classifier  precision  recall
# 0       d1       original         nc       0.50     0.8
# 1       d1       original        knn       0.45     1.0
# 2       d1       original         dt       0.57     0.8
# 3       d1     normalized         nc       0.36     0.8
# 4       d1     normalized        knn       0.45     1.0
# 5       d1     normalized         dt       0.57     0.8
# 6       d1      eigen (k)         nc       0.57     0.8
# 7       d1      eigen (k)        knn       0.56     1.0
# 8       d1      eigen (k)         dt       0.42     1.0
# 9       d1     eigen (2k)         nc       0.60     0.6
# 10      d1     eigen (2k)        knn       0.44     0.8
# 11      d1     eigen (2k)         dt       0.62     1.0
# 12      d2       original         nc       0.33     1.0
# 13      d2       original        knn       0.36     1.0
# 14      d2       original         dt       0.50     1.0
# 15      d2     normalized         nc       0.38     1.0
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=False)
sns.set(font_scale = 1.5)

box1 = sns.boxplot(ax = axes[0], data=df_control_pr, x="dataset", y="precision", color = "lightgreen", whis = 7 )
box4 = sns.boxplot(ax = axes[1], data=df_control_pr, x="dataset", y="recall", color = "lightgreen", whis = 7 )

box1.set(xlabel="A")
box4.set(xlabel="D")

box1.set_ylabel('precision', fontsize = 25)
box4.set_ylabel('recall', fontsize = 25)

box1.set_xticklabels(box1.get_xticklabels(), size = 20)
box4.set_xticklabels(box4.get_xticklabels(), size = 20)

fig.subplots_adjust(wspace=0.25)
fig.savefig("exp2_3.pdf", bbox_inches='tight')

# %%
df_control_pr.groupby('dataset').mean()
