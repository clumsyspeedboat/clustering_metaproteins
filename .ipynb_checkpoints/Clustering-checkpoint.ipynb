# %%
import pandas as pd                                  # dataframe manipulation
import numpy as np                                   # linear algebra
import seaborn as sns                                # visualization
sns.set_style('darkgrid')
import matplotlib.pyplot as plt                      # visualization
# %matplotlib inline
from yellowbrick.cluster import KElbowVisualizer     # cluster visualizer

# sklearn
from sklearn.datasets import load_digits             
from sklearn.decomposition import PCA
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.model_selection import train_test_split
from sklearn.metrics.cluster import contingency_matrix

# pyclustering
from pyclustering.cluster.kmeans import kmeans
from pyclustering.utils.metric import distance_metric
from pyclustering.cluster.center_initializer import random_center_initializer
from pyclustering.cluster.encoder import type_encoding
from pyclustering.cluster.encoder import cluster_encoder

# %config InlineBackend.figure_format = 'retina'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-e1cafa513dd7> in <module>
#       5 import matplotlib.pyplot as plt                      # visualization
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 7 from yellowbrick.cluster import KElbowVisualizer     # cluster visualizer
#       8
#       9 # sklearn
#
# c:\users\49171\appdata\local\programs\python\python38\lib\site-packages\yellowbrick\__init__.py in <module>
#      35 # Import yellowbrick functionality to the top level
#      36 # TODO: review top-level functionality
# ---> 37 from .anscombe import anscombe
#      38 from .datasaurus import datasaurus
#      39 from .classifier import ROCAUC, ClassBalance, ClassificationScoreVisualizer
#
# c:\users\49171\appdata\local\programs\python\python38\lib\site-packages\yellowbrick\anscombe.py in <module>
#      21 import matplotlib.pyplot as plt
#      22
# ---> 23 from yellowbrick.bestfit import draw_best_fit
#      24 from yellowbrick.style import get_color_cycle
#      25
#
# c:\users\49171\appdata\local\programs\python\python38\lib\site-packages\yellowbrick\bestfit.py in <module>
#      23 from sklearn import linear_model
#      24 from sklearn.preprocessing import PolynomialFeatures
# ---> 25 from sklearn.pipeline import make_pipeline
#      26 from sklearn.metrics import mean_squared_error as mse
#      27
#
# ModuleNotFoundError: No module named 'sklearn.pipeline'

# %%
# Save dataset into dataframe
df_hf = pd.read_csv('Heart Failure Prediction.csv')
df_mp = pd.read_csv('Dataset_Metaprotein.csv')
df_fc = pd.read_csv('Flu_Classification.csv')
df_diabetes = pd.read_csv('diabetes_health_indicators.csv')

# %%
df_hf
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
# K-means on Heart Failure Prediction Dataset

X_hf = df_hf.iloc[:, 0:12].values # feature matrix
y_hf = df_hf.iloc[:, -1].values # class matrix

# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1, 11))

visualizer.fit(X) # Fit the data to the visualizer
visualizer.show() # Finalize and render the figure
plt.show()

# df_k = PCA(2).fit_transform(df)
# kmeans = KMeans(n_clusters=3, init = 'k-means++', max_iter = 300, ).fit(df_hf)
# label = kmeans.fit_predict(df_hf)
# u_labels = np.unique(label)

# for i in u_labels:
#     plt.scatter(df_k[label == i , 0] , df_k[label == i , 1] , label = i)
    
# plt.legend()
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f6ceaee4a4a4> in <module>
#       6 # Instantiate the clustering model and visualizer
#       7 model = KMeans()
# ----> 8 visualizer = KElbowVisualizer(model, k=(1, 11))
#       9
#      10 visualizer.fit(X) # Fit the data to the visualizer
#
# NameError: name 'KElbowVisualizer' is not defined

# %%
kmeans.get_params()
# Out:
# {'algorithm': 'auto',
#  'copy_x': True,
#  'init': 'k-means++',
#  'max_iter': 300,
#  'n_clusters': 3,
#  'n_init': 10,
#  'n_jobs': 'deprecated',
#  'precompute_distances': 'deprecated',
#  'random_state': None,
#  'tol': 0.0001,
#  'verbose': 0}

# %%
dbclust = DBSCAN(eps = 0.9, min_samples = 5).fit(df_k)
